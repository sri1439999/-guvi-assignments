# %% [markdown]
# <a href="https://colab.research.google.com/github/sri1439999/-guvi-assignments/blob/main/mytask1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import re
import difflib
def validate_email(x):
  check="^[a-zA-Z0-9-._]+@[a-zA-Z0-9]+\.[a-z]{1,3}$"
  if re.match(check,x):
    return True
  else:
   print('ERROR: Please enter correct format mail id')
def spln(x):
 c=0
 for i in range(len(x)):
  if x[i] in '[@_!#$%^&*()<>?/\|}{~:]':
    c=c+1
 if c>0:
   return True
 else:
   return False
def capital(x):
 a=0
 for i in x:
    if i.isupper():
      a=a+1
 if a>0:
  return True
def small(x):
 a=0
 for i in x:
   if i.isupper():
     a=a+1
 if a>0:
  return True
def num(x):
 a=0
 for i in x:
    if i.isnumeric():
      a=a+1
 if a>0:
  return True

def login(x):
   now=input('welcome to log in page   Login   or   Forgot password:    ')
   if now=='Forgot password':
      Email_id=input('Enter the email id:  ')
      em=open('user_data1','r')
      check=em.read()
      abcd=check.splitlines()
      sw=0
      for i in range(len(abcd)):
        if Email_id==abcd[i]:
            Pass=abcd[i+1]
            print("\n"+"\n"'Your mail is:  ',Email_id)
            print("\n"+'Your pass word is:   ',Pass) 
            print("\n"+'ThankYou u can do log in now with Your credentials')
            sw=sw+1
      if sw==0:
          print('Dear User Your username or mail id not exist please do register ')
      
   else:
    Email_id=input('Enter the email id:  ')
    password=input('Enter the password:  ')
    em=open('user_data1','r')
    check=em.read()
    abcd=check.splitlines()
    dum=0
    for i in range(len(abcd)):
      if abcd[i]==Email_id and abcd[i+1]==password:
          dum=dum+1
    if dum>0:
      print('welcome to Your page')
    else:
      print("Dear user Your username or mailid does'texist kindly do Register THANKYOU")
    em.close()



def validate_password(x):
  if spln(x)==True:
    if num(x)==True:
      if capital(x)==True:
        if small(x)==True:
           print("Email_id and password validated")
           em=open('user_data1','a')
           em.write(Email_id+'\n'+password+'\n')
           em.close()
           print("THANKOU your data havebeen saved so You can do login")
           login(x)
        else:
          print('ERROR: Password must contain atlest one lower case charcter')
      else:
        print('ERROR: Password must contain atlest one upper case charcter')
    else:
      print('ERROR: Password must contain atlest one digit')
  else:
    print('ERROR: Password must contain atlest one special character')
           
print("Hi... Welcome")  
print("please do register if you are new to this page")   
user_input=input("Choose   Login  OR   Register:   ")
if (user_input=='Register') or (user_input=='Login'):
  if user_input=='Register':
    Email_id=input("Enter your Email or User name :   ")
    if Email_id[0]  in ['0123456789`~!@#$%^&*()_[{]}\|;:,<.>/?']:
        print('ERROR: Please enter correct format first letter must be an alphabet')   
    else:
        if validate_email(Email_id) ==True:
          password=input('Enter Password:    ')
          s=len(password)
          if s>5 and s<16:
            validate_password(password)
          else:
            print('ERROR: Password length must be in 5 to 16 characters')

  if user_input=='Login':
    now=input('welcome to log in page   Login  or  Forgot password:    ')
    if now=='Forgot password':
      Email_id=input('Enter the email id:  ')
      em=open('user_data1','r')
      check=em.read()
      abcd=check.splitlines()
      sw=0
      for i in range(len(abcd)):
        if Email_id==abcd[i]:
            Pass=abcd[i+1]
            print("\n"+"\n"'Your mail is:  ',Email_id)
            print("\n"+'Your pass word is:   ',Pass) 
            print("\n"+'ThankYou u can do log in now with Your credentials')
            sw=sw+1
      if sw==0:
          print("Dear user Your username or mailid does'texist kindly do Register THANKYOU")
      
    elif now=='Login':
      Email_id=input('Enter the email id:  ')
      password=input('Enter the password:  ')
      

      em=open('user_data1','r')
      check=em.read()
      abcd=check.splitlines()
      dum=0
      for i in range(len(abcd)):
        if abcd[i]==Email_id and abcd[i+1]==password:
            dum=dum+1
      if dum>0:
        print('Dear user welcome to Your page')
      else:
        print("Dear user Your username or mailid does'texist kindly do Register THANKYOU")
      em.close()
    else:
      print("Dear user  kindly Choose with in the option Login or  Forgot password ")
    
else:
  print(" Dear User  kindly Choose with in the option Login or Register")
# Out:
# Hi... Welcome
# please do register if you are new to this page
# Choose   Login  OR   Register:   kas
#  Dear User  kindly Choose with in the option Login or Register
